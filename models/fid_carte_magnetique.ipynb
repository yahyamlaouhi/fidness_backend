# %%
#Connect to mysql
import pymysql
import pandas as pd
import numpy as np
conn=pymysql.connect(host='localhost',port=int(3308),user='root',passwd='',db='fidness')

# %%
#select user table
df=pd.read_sql_query("SELECT * FROM fid_carte_magnetique ",conn)
df.head(100)
# Out:
#                            email_responsable                     enseigne  \
# 0                         contact@zenhome.tn                     zen home
# 1                  contact@tunisieenligne.tn                    carrefour
# 2                      benyaghlane@gmail.com                 ben yaghlane
# 3                    client@exist-fashion.tn                        exist
# 4                        tuniscity@gmail.com                        geant
# ..                                       ...                          ...
# 84                            hurma@yahoo.fr                        hurma
# 85                       contact@hbyomar.com  patisserie hachicha by omar
# 86                         aecor@hotmail.com                     aecor.tn
# 87                   ptitange2nasr@gmail.com                   p'tit ange
# 88  direction.mallofsousse@indigoproperty.tn               mall of sousse
#
#     id_admin_creation  telephone  id  id_secteur_activite  \
# 0                   1   92358357   1                  198
# 1                   1   70248248   2                  254
# 2                   1   29614136   3                  253
# 3                   1   36400404   4                  258
# 4                   1   31305858   5                  254
# ..                ...        ...  ..                  ...
# 84                  1   98556550  85                  258
# 85                  1   29606060  86                  211
# 86                  1   20400200  87                  251
# 87                  1   26232047  88                    1
# 88                  1   70555880  89                  254
#
#                                email_contact       date_creation
# 0                        zengroup@zen.com.tn 2021-07-05 18:43:52
# 1                  contact@tunisieenligne.tn 2021-07-05 21:09:58
# 2                      benyaghlane@gmail.com 2021-07-05 21:38:22
# 3                    client@exist-fashion.tn 2021-07-05 22:02:34
# 4                        tuniscity@gmail.com 2021-07-12 09:13:41
# ..                                       ...                 ...
# 84                             info@hurma.tn 2022-05-20 14:31:14
# 85                       contact@hbyomar.com 2022-05-21 10:40:18
# 86                           aecor@gmail.com 2022-05-21 11:53:55
# 87                   ptitange2nasr@gmail.com 2022-05-21 12:50:59
# 88  direction.mallofsousse@indigoproperty.tn 2022-05-21 13:45:14
#
# [89 rows x 8 columns]

# %%
#verifiy null values
df.isnull().sum()
# Out:
# email_responsable      0
# enseigne               0
# id_admin_creation      0
# telephone              0
# id                     0
# id_secteur_activite    0
# email_contact          0
# date_creation          0
# dtype: int64

# %%
#exportiiiing
from sqlalchemy import create_engine
engine = create_engine('mysql+pymysql://root:@localhost:3308/fid_db')
df.to_sql(name='fid_carte_magnetique',con=engine,if_exists='replace')

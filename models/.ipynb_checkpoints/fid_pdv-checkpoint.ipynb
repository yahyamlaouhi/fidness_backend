# %%
#Connect to mysql
import pymysql
import pandas as pd
import numpy as np
conn=pymysql.connect(host='localhost',port=int(3308),user='root',passwd='',db='fidness')

# %%
#select user table
df=pd.read_sql_query("SELECT * FROM fid_pdv ",conn)
df.head(100)
# Out:
#    code_postal  id_admin_creation  id_marque  titre_responsable  \
# 0         1082                  1         16  DIRECTEUR GENERAL
# 1         2076                  1         29  DIRECTEUR GENERAL
# 2         1053                  1         33            GERANTE
# 3         2076                  1          2            GERANTE
# 4         2091                  1         38            GERANTE
# ..         ...                ...        ...                ...
# 80        2092                  1        107             GERANT
# 81        2091                  1        108            GERANTE
# 82        2091                  1        109             GERANT
# 83        2076                  1        110            GERANTE
# 84        2076                  1         96             GERANT
#
#     id_gouvernorat telephone nom_prenom_responsable       date_creation  \
# 0               23  98215967        gAAAAABijMOVyAI 2021-09-07 09:11:01
# 1               23  22641431        gAAAAABijMOVWDl 2021-09-07 11:44:13
# 2               23  23152000        gAAAAABijMOVUTP 2021-09-07 20:43:35
# 3               23  54360414        gAAAAABijMOVXny 2021-09-08 16:44:52
# 4                1  94306482        gAAAAABijMOV3yH 2021-09-08 21:41:57
# ..             ...       ...                    ...                 ...
# 80              23  92225123        gAAAAABijMOVdGB 2022-04-10 13:39:45
# 81               1  71723947        gAAAAABijMOVzBE 2022-04-10 14:12:45
# 82               1  98218353        gAAAAABijMOVa55 2022-04-12 15:04:37
# 83              23  27306111        gAAAAABijMOVsQ8 2022-04-19 11:48:07
# 84              23  24077319        gAAAAABijMOVWS- 2022-04-20 10:24:43
#
#    email_responsable                             enseigne  id_carte_fidelite  \
# 0    hafsaagr***.xyz              carte de fidelite hafsa                  1
# 1    RAHMA@LO***.xyz               carte de fidelite looh                  2
# 2    benghali***.xyz         carte de fidelite ms. marion                  3
# 3    molka@kh***.xyz             carte de fidelite khalta                  4
# 4    monbijou***.xyz  carte de fidelite mon bijou macaron                  5
# ..               ...                                  ...                ...
# 80   sozibeau***.xyz                carte fid sozi beauta                 85
# 81   FLEURDEL***.xyz       carte de fidelite fleur de lys                 86
# 82   LACAVE@H***.xyz  carte de fidelite la cave gourmande                 87
# 83   ECHAREK@***.xyz   carte de fidelite p'ti dej echarek                 88
# 84   LACARTEG***.xyz                       carte fid gold                 89
#
#    telephone_responsable  id                    email_contact
# 0               98******   1          hafsaagrifood@gmail.com
# 1               22******   2                   RAHMA@LOOH.COM
# 2               23******   3            contact@ms-marion.com
# 3               54******   4                hi@khaltashop.com
# 4               94******   5  monbijoumacaronmanzeh@yahoo.com
# ..                   ...  ..                              ...
# 80              92******  81             sozibeaute@gmail.com
# 81              71******  82        fetenfleurdelys@gmail.com
# 82              98******  83       lacavegourmande1@gmail.com
# 83              27******  84        petitdejecharek@gmail.com
# 84              24******  85         rayenlibrairie@gmail.com
#
# [85 rows x 14 columns]

# %%
#verifiy null values
df.isnull().sum()
# Out:
# id                        0
# id_marque                 0
# enseigne                  0
# id_carte_fidelite         0
# id_gouvernorat            0
# code_postal               0
# adresse                   0
# telephone                 0
# email_contact             0
# latitude                 53
# longitude                53
# nom_responsable           0
# prenom_responsable        0
# titre_responsable         0
# telephone_responsable     0
# email_responsable         0
# date_creation             0
# id_admin_creation         0
# dtype: int64

# %%
df=df.dropna(axis=1)
df
# Out:
#    code_postal  id_admin_creation  id_marque  titre_responsable  \
# 0         1082                  1         16  DIRECTEUR GENERAL
# 1         2076                  1         29  DIRECTEUR GENERAL
# 2         1053                  1         33            GERANTE
# 3         2076                  1          2            GERANTE
# 4         2091                  1         38            GERANTE
# ..         ...                ...        ...                ...
# 80        2092                  1        107             GERANT
# 81        2091                  1        108            GERANTE
# 82        2091                  1        109             GERANT
# 83        2076                  1        110            GERANTE
# 84        2076                  1         96             GERANT
#
#     id_gouvernorat telephone nom_prenom_responsable       date_creation  \
# 0               23  98215967        gAAAAABijMOVyAI 2021-09-07 09:11:01
# 1               23  22641431        gAAAAABijMOVWDl 2021-09-07 11:44:13
# 2               23  23152000        gAAAAABijMOVUTP 2021-09-07 20:43:35
# 3               23  54360414        gAAAAABijMOVXny 2021-09-08 16:44:52
# 4                1  94306482        gAAAAABijMOV3yH 2021-09-08 21:41:57
# ..             ...       ...                    ...                 ...
# 80              23  92225123        gAAAAABijMOVdGB 2022-04-10 13:39:45
# 81               1  71723947        gAAAAABijMOVzBE 2022-04-10 14:12:45
# 82               1  98218353        gAAAAABijMOVa55 2022-04-12 15:04:37
# 83              23  27306111        gAAAAABijMOVsQ8 2022-04-19 11:48:07
# 84              23  24077319        gAAAAABijMOVWS- 2022-04-20 10:24:43
#
#    email_responsable                             enseigne  id_carte_fidelite  \
# 0    hafsaagr***.xyz              carte de fidelite hafsa                  1
# 1    RAHMA@LO***.xyz               carte de fidelite looh                  2
# 2    benghali***.xyz         carte de fidelite ms. marion                  3
# 3    molka@kh***.xyz             carte de fidelite khalta                  4
# 4    monbijou***.xyz  carte de fidelite mon bijou macaron                  5
# ..               ...                                  ...                ...
# 80   sozibeau***.xyz                carte fid sozi beauta                 85
# 81   FLEURDEL***.xyz       carte de fidelite fleur de lys                 86
# 82   LACAVE@H***.xyz  carte de fidelite la cave gourmande                 87
# 83   ECHAREK@***.xyz   carte de fidelite p'ti dej echarek                 88
# 84   LACARTEG***.xyz                       carte fid gold                 89
#
#    telephone_responsable  id                    email_contact
# 0               98******   1          hafsaagrifood@gmail.com
# 1               22******   2                   RAHMA@LOOH.COM
# 2               23******   3            contact@ms-marion.com
# 3               54******   4                hi@khaltashop.com
# 4               94******   5  monbijoumacaronmanzeh@yahoo.com
# ..                   ...  ..                              ...
# 80              92******  81             sozibeaute@gmail.com
# 81              71******  82        fetenfleurdelys@gmail.com
# 82              98******  83       lacavegourmande1@gmail.com
# 83              27******  84        petitdejecharek@gmail.com
# 84              24******  85         rayenlibrairie@gmail.com
#
# [85 rows x 14 columns]

# %%
#exportiiiing
from sqlalchemy import create_engine
engine = create_engine('mysql+pymysql://root:@localhost:3308/fid_db')
df.to_sql(name='fid_pdv',con=engine,if_exists='replace')
